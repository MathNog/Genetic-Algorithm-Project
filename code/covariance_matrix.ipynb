# %%
import pandas as pd
import numpy as np

# %%
returns = pd.read_csv("../data/predicted_returns_naive.csv",index_col="Date")
volatilities = pd.read_csv("../data/volatility_garch_1_1_14.csv",index_col="Date")

returns.fillna(method="backfill",inplace=True)
volatilities.fillna(method="backfill",inplace=True)

# %%
returns
# Out:
#             ABEV3.SA  BBAS3.SA  BBDC4.SA  CPLE6.SA  CSAN3.SA  CSNA3.SA  \
# Date
# 2010-01-04  0.038580  0.029609  0.018519  0.032145 -0.054668  0.039757
# 2010-01-11  0.038580  0.029609  0.018519  0.032145 -0.054668  0.039757
# 2010-01-18  0.019564 -0.019300 -0.026413 -0.014484 -0.010191  0.005033
# 2010-01-25  0.000125 -0.024573 -0.126902 -0.010667 -0.022880 -0.074747
# 2010-02-01 -0.058269 -0.015537 -0.014261  0.032703 -0.072430  0.025784
# ...              ...       ...       ...       ...       ...       ...
# 2021-11-29 -0.041086  0.057197 -0.005372 -0.026103  0.011332  0.040766
# 2021-12-06 -0.042221  0.059397  0.016513  0.026103  0.049014  0.043905
# 2021-12-13 -0.003130  0.009274 -0.025893  0.033257 -0.004929  0.046168
# 2021-12-20  0.007495 -0.069103 -0.019486  0.000000 -0.005405  0.043738
# 2021-12-27 -0.032894 -0.031840 -0.029700 -0.015699 -0.028727 -0.032724
#
#             ELET3.SA  ENBR3.SA  GGBR4.SA  ITUB4.SA  JBSS3.SA  PETR4.SA  \
# Date
# ...

# %%
volatilities
# Out:
#                ABEV3     BBAS3     BBDC4     CPLE6     CSAN3     CSNA3  \
# Date
# 2010-01-04  0.023696  0.030206  0.015181  0.023119  0.032747  0.042847
# 2010-01-11  0.023696  0.030206  0.015181  0.023119  0.032747  0.042847
# 2010-01-18  0.023696  0.030206  0.015181  0.023119  0.032747  0.042847
# 2010-01-25  0.023696  0.030206  0.015181  0.023119  0.032747  0.042847
# 2010-02-01  0.023696  0.030206  0.015181  0.023119  0.032747  0.042847
# ...              ...       ...       ...       ...       ...       ...
# 2021-11-29  0.051437  0.042720  0.023819  0.042394  0.042951  0.056186
# 2021-12-06  0.051195  0.045227  0.022037  0.032672  0.044189  0.060762
# 2021-12-13  0.046650  0.042257  0.020549  0.031646  0.042129  0.061688
# 2021-12-20  0.031948  0.049432  0.019234  0.021344  0.032168  0.057170
# 2021-12-27  0.042110  0.048081  0.020325  0.020402  0.037799  0.043970
#
#                ELET3     ENBR3     GGBR4     ITUB4     JBSS3     PETR4  \
# Date
# ...

# %%
window = 14

returns.iloc[0:window,:].cov()
# Out:
#            ABEV3.SA  BBAS3.SA  BBDC4.SA      CPLE6.SA  CSAN3.SA  CSNA3.SA  \
# ABEV3.SA   0.000988  0.000409  0.000366  1.251319e-04 -0.000110  0.000303
# BBAS3.SA   0.000409  0.000939  0.000898  6.998019e-04  0.000155  0.000778
# BBDC4.SA   0.000366  0.000898  0.001677  6.131702e-04 -0.000042  0.001365
# CPLE6.SA   0.000125  0.000700  0.000613  1.003605e-03 -0.000478  0.000594
# CSAN3.SA  -0.000110  0.000155 -0.000042 -4.779679e-04  0.002148 -0.000343
# CSNA3.SA   0.000303  0.000778  0.001365  5.943034e-04 -0.000343  0.001820
# ELET3.SA   0.001519  0.001236  0.000812  2.102232e-03 -0.003833  0.000745
# ENBR3.SA   0.000624  0.000632  0.000762  6.400980e-04 -0.000328  0.000466
# GGBR4.SA   0.000339  0.000858  0.001407  5.695927e-04  0.000108  0.001134
# ITUB4.SA   0.000152  0.000761  0.000846  5.815597e-04 -0.000226  0.000856
# JBSS3.SA   0.000867  0.000853  0.000917  6.345758e-04 -0.001038  0.001005
# PETR4.SA   0.000272  0.000789  0.000900  6.671664e-04 -0.000362  0.001013
# ...

# %%
np.var(returns["ABEV3.SA"])
# Out:
# 0.0012375697761786864
